# %% [markdown]
# <a href="https://colab.research.google.com/github/mahananda123/Data_Integration/blob/main/Data_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Data Integration

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# ###Concatenation
#
# Documentation
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html

# %%
df_1=df[['longitude','latitude','median_income']].sample(n=5)
df_2=df[['longitude','latitude','median_income']].sample(n=5)
df_3=df[['longitude','latitude','median_income']].sample(n=5)

# %%
df_1
# Out:
#       longitude  latitude  median_income
# 2818    -122.54     38.14         7.5412
# 2554    -117.34     34.12         3.3516
# 2285    -121.63     39.10         4.1740
# 1736    -119.23     35.74         2.0330
# 1677    -118.31     33.72         4.1451

# %%
df_2
# Out:
#       longitude  latitude  median_income
# 1994    -118.10     33.98         3.5268
# 2787    -121.80     36.69         3.4239
# 1715    -118.44     34.24         4.0950
# 2643    -119.62     36.59         4.0197
# 2083    -117.22     33.22         1.7217

# %%
df_3
# Out:
#       longitude  latitude  median_income
# 1932    -118.13     33.84         6.3364
# 2459    -119.64     36.85         4.9904
# 2473    -117.87     33.84         4.5112
# 2670    -119.32     36.19         3.3350
# 267     -120.23     37.96         2.0057

# %%
df_cat1=pd.concat([df_1,df_2,df_3],axis=0)
df_cat1
# Out:
#       longitude  latitude  median_income
# 2818    -122.54     38.14         7.5412
# 2554    -117.34     34.12         3.3516
# 2285    -121.63     39.10         4.1740
# 1736    -119.23     35.74         2.0330
# 1677    -118.31     33.72         4.1451
# 1994    -118.10     33.98         3.5268
# 2787    -121.80     36.69         3.4239
# 1715    -118.44     34.24         4.0950
# 2643    -119.62     36.59         4.0197
# 2083    -117.22     33.22         1.7217
# 1932    -118.13     33.84         6.3364
# 2459    -119.64     36.85         4.9904
# 2473    -117.87     33.84         4.5112
# 2670    -119.32     36.19         3.3350
# 267     -120.23     37.96         2.0057

# %%
df_cat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 2818 to 267
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   longitude      15 non-null     float64
#  1   latitude       15 non-null     float64
#  2   median_income  15 non-null     float64
# dtypes: float64(3)
# memory usage: 480.0 bytes

# %%
df_cat2=pd.concat([df_1,df_2,df_3],axis=1)
df_cat2
# Out:
#       longitude  latitude  median_income  longitude  latitude  median_income  \
# 2818    -122.54     38.14         7.5412        NaN       NaN            NaN
# 2554    -117.34     34.12         3.3516        NaN       NaN            NaN
# 2285    -121.63     39.10         4.1740        NaN       NaN            NaN
# 1736    -119.23     35.74         2.0330        NaN       NaN            NaN
# 1677    -118.31     33.72         4.1451        NaN       NaN            NaN
# 1994        NaN       NaN            NaN    -118.10     33.98         3.5268
# 2787        NaN       NaN            NaN    -121.80     36.69         3.4239
# 1715        NaN       NaN            NaN    -118.44     34.24         4.0950
# 2643        NaN       NaN            NaN    -119.62     36.59         4.0197
# 2083        NaN       NaN            NaN    -117.22     33.22         1.7217
# 1932        NaN       NaN            NaN        NaN       NaN            NaN
# 2459        NaN       NaN            NaN        NaN       NaN            NaN
# 2473        NaN       NaN            NaN        NaN       NaN            NaN
# 2670        NaN       NaN            NaN        NaN       NaN            NaN
# 267         NaN       NaN            NaN        NaN       NaN            NaN
#
#       longitude  latitude  median_income
# 2818        NaN       NaN            NaN
# 2554        NaN       NaN            NaN
# 2285        NaN       NaN            NaN
# 1736        NaN       NaN            NaN
# 1677        NaN       NaN            NaN
# 1994        NaN       NaN            NaN
# 2787        NaN       NaN            NaN
# 1715        NaN       NaN            NaN
# 2643        NaN       NaN            NaN
# 2083        NaN       NaN            NaN
# 1932    -118.13     33.84         6.3364
# 2459    -119.64     36.85         4.9904
# 2473    -117.87     33.84         4.5112
# 2670    -119.32     36.19         3.3350
# 267     -120.23     37.96         2.0057

# %%
df_cat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 2818 to 267
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   longitude      5 non-null      float64
#  1   latitude       5 non-null      float64
#  2   median_income  5 non-null      float64
#  3   longitude      5 non-null      float64
#  4   latitude       5 non-null      float64
#  5   median_income  5 non-null      float64
#  6   longitude      5 non-null      float64
#  7   latitude       5 non-null      float64
#  8   median_income  5 non-null      float64
# dtypes: float64(9)
# memory usage: 1.2 KB

# %%
df1=df[['longitude']][:5]
df2=df[['latitude']][:5]
df3=df[['median_income']][:5]
df1,df2,df3
# Out:
# (   longitude
#  0    -122.05
#  1    -118.30
#  2    -117.81
#  3    -118.36
#  4    -119.67,
#     latitude
#  0     37.37
#  1     34.26
#  2     33.78
#  3     33.82
#  4     36.33,
#     median_income
#  0         6.6085
#  1         3.5990
#  2         5.7934
#  3         6.1359
#  4         2.9375)

# %%
df_cat3=pd.concat([df1,df2,df3],axis=1)
df_cat3
# Out:
#    longitude  latitude  median_income
# 0    -122.05     37.37         6.6085
# 1    -118.30     34.26         3.5990
# 2    -117.81     33.78         5.7934
# 3    -118.36     33.82         6.1359
# 4    -119.67     36.33         2.9375

# %% [markdown]
# ###Merging
#
# Documentation
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
df_1=df[['longitude','median_income']][:5]
df_1
# Out:
#    longitude  median_income
# 0    -122.05         6.6085
# 1    -118.30         3.5990
# 2    -117.81         5.7934
# 3    -118.36         6.1359
# 4    -119.67         2.9375

# %%
df_2=df[['longitude','median_house_value']][:5]
df_2
# Out:
#    longitude  median_house_value
# 0    -122.05            344700.0
# 1    -118.30            176500.0
# 2    -117.81            270500.0
# 3    -118.36            330000.0
# 4    -119.67             81700.0

# %%
pd.merge(df_1,df_2,on=['longitude'],how='inner')
# Out:
#    longitude  median_income  median_house_value
# 0    -122.05         6.6085            344700.0
# 1    -118.30         3.5990            176500.0
# 2    -117.81         5.7934            270500.0
# 3    -118.36         6.1359            330000.0
# 4    -119.67         2.9375             81700.0

# %%
df_3=df[['longitude','population']][2:7]
df_3
# Out:
#    longitude  population
# 2    -117.81      1484.0
# 3    -118.36        49.0
# 4    -119.67       850.0
# 5    -119.56       663.0
# 6    -121.43       604.0

# %%
pd.merge(df_1,df_3,on='longitude',how='inner')
# Out:
#    longitude  median_income  population
# 0    -117.81         5.7934      1484.0
# 1    -118.36         6.1359        49.0
# 2    -119.67         2.9375       850.0

# %%
pd.merge(df_1,df_3,on='longitude',how='outer').drop_duplicates()
# Out:
#    longitude  median_income  population
# 0    -122.05         6.6085         NaN
# 1    -118.30         3.5990         NaN
# 2    -117.81         5.7934      1484.0
# 3    -118.36         6.1359        49.0
# 4    -119.67         2.9375       850.0
# 5    -119.56            NaN       663.0
# 6    -121.43            NaN       604.0

# %% [markdown]
# ###Joining
# documentation
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html

# %%
df1=df[['longitude']][:5]
df1
# Out:
#    longitude
# 0    -122.05
# 1    -118.30
# 2    -117.81
# 3    -118.36
# 4    -119.67

# %%
df2=df[['latitude']][2:7]
df2
# Out:
#    latitude
# 2     33.78
# 3     33.82
# 4     36.33
# 5     36.51
# 6     38.63

# %%
df1.join(df2,how='left')
# Out:
#    longitude  latitude
# 0    -122.05       NaN
# 1    -118.30       NaN
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33

# %%
df1.join(df2,how='right')
# Out:
#    longitude  latitude
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33
# 5        NaN     36.51
# 6        NaN     38.63

# %%
df1.join(df2,how='inner')
# Out:
#    longitude  latitude
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33

# %%
df1.join(df2,how='outer')
# Out:
#    longitude  latitude
# 0    -122.05       NaN
# 1    -118.30       NaN
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33
# 5        NaN     36.51
# 6        NaN     38.63
